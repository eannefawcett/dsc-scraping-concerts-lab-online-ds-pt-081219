# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
#Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
from bs4 import BeautifulSoup
import requests
html_page = requests.get('https://www.residentadvisor.net/events')
soup = BeautifulSoup(html_page.content, 'html.parser')
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en,ja,es">
# <head id="_x1"><title>
# 	RA: Events in Texas, United States of America
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en,ja,es" http-equiv="content-language"/><meta content="RA: Resident Advisor" name="Description"/><meta content="RA, residentadvisor, resident, advisor, music, ra, events, in, texas, united, states, america" name="Keywords"/><meta content="Resident Advisor" name="Author"/><meta content="Resident Advisor" property="og:site_name"/><meta content="712773712080127" property="fb:app_id"/><link href="/bundles/default-css?v=ATv7yC5anBBrxJoYdSr-DqUPyab_mqaaXHG0qxMzlYI1" rel="stylesheet"/>
# <meta content="app-id=981952703, app-argument=ra-guide://search" name="apple-itunes-app"/><link href="/bundles/cat-listings-css?v=qgpSmyPbylOKeJFqy2yvCrTgAsw9yQYcJtLKS_vPO6s1" rel="stylesheet"/>
# <link href="/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link color="#000000" href="/images/ra_icon.svg" rel="mask-icon"/><script src="/bundles/default-js?v=3qaUNnKRH_PXCPLvCCsp5HpmkPv6G-3JQuMc2B329WA1"></script>
# <script>
# 	    googletag.cmd.push(function () { googletag.pubads().setTargeting("Page", "/events/us/texas").setTargeting("Category", "Listings").setTargeting("Section", "Events").setTargeting("Content", "EventsHome").setTargeting("Country", "US").setTargeting("Area", "Texas"); });
#          console.info('Interested in our code? Join us and help write it - https://www.residentadvisor.net/about/jobs');
#     </script>
# <script>
#             const widthTest = false;
#         if (window.screen.availWidth < 663 && window.screen.width < window.screen.height && !widthTest) {
#             document.write('<meta name="viewport" content="width=328">');
#         } else {
#             document.write('<meta name="viewport" content="width=device-width, initial-scale=1">');
#         }
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-940832047"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#             function gtag() { dataLayer.push(arguments); }
#             gtag('js', new Date());
#
#             gtag('config', 'AW-940832047');
#         </script>
# <script src="/js/dist/ReactLibs.bundle.js?637093252422873029"></script>
# <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#                     })(window, document, 'script', 'dataLayer', 'GTM-M269WMP');
#         </script>
# </head>
# <body id="body">
# <input id="user-id" name="user-id" type="hidden" value="0"/>
# <input id="see-ngc" name="see-ngc" type="hidden" value="false"/>
# <a name="top"></a>
# <header id="header">
# <div class="pnlLeaderWrapper">
# <div id="pnlLeader">
# <aside class="div-gpt-ad-1452773484957-6 leader"><div class="ad" id="div-gpt-ad-1452773484957-6"></div></aside>
# </div>
# </div>
# <nav class="clearfix" id="user">
# <ul style="-moz-user-select: -moz-none; -khtml-user-select: none; -webkit-user-select: none;">
# <li class="but dark arrow-down" id="basket">
# Basket
# <div class="count basket" style="display:none;"><span></span></div>
# </li>
# <li class="but dark desktop-only desktop-wide-only" id="nav-link"><a href="https://www.doorsopen.co/#utm_source=RA&amp;utm_medium=Header-link" target="_blank"><span>Music Jobs</span></a></li>
# <li class="but arrow-down temp login" id="profile">Login / Register</li>
# </ul>
# </nav>
# <ul class="bbox panel" id="profile-panel">
# <li><a href="https://www.residentadvisor.net/login">Login</a></li>
# <li><a href="https://www.residentadvisor.net/register">Register</a></li>
# </ul>
# <div class="bbox panel bbox generic clearfix" id="basket-panel">
# <div class="items"></div><div class="basket-but but myra"></div>
# </div>
# <div class="notificationPanel bbox clearfix events col3" id="notificationPanel"></div><div class="null" id="navContainer">
# <div id="navbar">
# <div id="logo"><a class="icon" href="/">Resident Advisor</a></div>
# <div class="modal-full-screen" id="search-bar">
# <span class="modal-close">×</span>
# <div class="modal-body" id="search-bar-internal">
# <span class="f24 mobile-only search-header">Search</span>
# <div id="search-box-div">
# <input id="search-box" placeholder="Artists, Clubs, Promoters, Cities" type="text"/>
# </div>
# <div class="but large" id="search-button">
# <a id="search" title="Search">Submit</a>
# </div>
# <div class="grey pt16 search-helper" style="display: none;">Did you mean</div>
# </div>
# </div>
# <nav class="modal-full-screen" id="nav" role="navigation">
# <div class="modal-close">×</div>
# <ul class="modal-body open" data-display="0" id="links">
# <li class="mobile-only tablet-off">
# <div id="logo-modal-nav">
# <a class="icon" ga-event-action="RA-Logo" ga-event-category="nav" ga-on="click" href="/">Resident Advisor</a>
# </div>
# </li>
# <li id="mMagazine">
# <span>
# Magazine</span>
# <ul>
# <li id="mNews"><a ga-event-action="News" ga-event-category="nav" ga-on="click" href="/news">
# News</a></li>
# <li id="mReviews"><a ga-event-action="Reviews" ga-event-category="nav" ga-on="click" href="/reviews.aspx">
# Reviews</a></li>
# <li id="mFeatures"><a ga-event-action="Features" ga-event-category="nav" ga-on="click" href="/features.aspx">
# Features</a></li>
# <li id="mFilms"><a ga-event-action="Videos" ga-event-category="nav" ga-on="click" href="/videos">
# Videos</a></li>
# </ul>
# </li>
# <li data-selected="1" id="mListings">
# <span>
# Listings</span>
# <ul>
# <li data-selected="1" id="mEvents"><a ga-event-action="Events" ga-event-category="nav" ga-on="click" href="/events">
# Events</a></li>
# <li id="mClubs"><a ga-event-action="Clubs" ga-event-category="nav" ga-on="click" href="/clubs.aspx">
# Clubs</a></li>
# <li id="mFestivals"><a ga-event-action="Festivals" ga-event-category="nav" ga-on="click" href="/festivals.aspx">
# Festivals</a></li>
# <li id="mPhotos"><a ga-event-action="Photos" ga-event-category="nav" ga-on="click" href="/photos.aspx">
# Photos</a></li>
# </ul>
# </li>
# <li id="mMusic">
# <span>
# Music</span>
# <ul>
# <li id="mDjpages"><a ga-event-action="Artists" ga-event-category="nav" ga-on="click" href="/dj.aspx">
# Artists</a></li>
# <li id="mMixOfTheDay"><a ga-event-action="Mix of the day" ga-event-category="nav" ga-on="click" href="/news/mix-of-the-day/2019/11">
# Mix of the day</a></li>
# <li id="mCharts"><a ga-event-action="DJ Charts" ga-event-category="nav" ga-on="click" href="/dj-charts.aspx">
# DJ Charts</a></li>
# <li id="mPodcast"><a ga-event-action="Podcasts" ga-event-category="nav" ga-on="click" href="/podcast.aspx">
# Podcasts</a></li>
# </ul>
# </li>
# <li data-url="https://search.residentadvisor.net/" id="mSearch">
# <a ga-event-action="reveal-desktop" ga-event-category="search" ga-on="click" href="#">
# Search</a>
# </li>
# </ul>
# </nav>
# <div ga-event-action="burger" ga-event-category="nav" ga-on="click" id="but-links">
# <div class="icon"></div>
# </div>
# <div ga-event-action="mobile-reveal" ga-event-category="search" ga-on="click" id="but-search">
# <div class="icon"></div>
# </div>
# </div>
# <div class="add-space" id="sectionHead">
# <h1>Events</h1>
# </div>
# <link href="/bundles/autocomplete-css?v=hX3EIxBPUes4W-JFrW9vc2V9eyRDs1p9rgi0LcnlXug1" rel="stylesheet"/>
# <script src="/bundles/autocomplete?v=SCtA5z9vnBIQK6ZI-wtyD14u0Lv-S6kQhwTW5lgrMYQ1"></script>
# <script src="/bundles/analytics-js?v=GRbOA-5b5S00wbAK8zMczxQRPgbblgKCy7f2bir0h281"></script>
# </div>
# <section class="clearfix" id="subnav">
# <ul>
# <li class="on" id="subnav-all"><a href="/events">All</a></li><li id="subnav-new"><a href="/events/new">New</a></li><li id="subnav-for-you"><a href="/events/favourites">For You</a></li><li id="subnav-promoters"><a href="/promoters.aspx">Promoters</a></li><li id="subnav-submit-an-event"><a href="/submit-event.aspx">Submit an event</a></li>
# </ul>
# </section>
# </header>
# <form action="./events" id="Form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="JJ/nACVh2aa6wEVJVuH0xlHLgW73mmR44UEtQJnttmdmraXGAiG4lp9a7fXqCHpYAv8k6tMfiKLAoCTHeex2mR1zS20="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="ADA4D364"/>
# </div>
# <main>
# <script src="/bundles/sticky-js?v=v676-NN9nrtj1Xpc3-lLALpuQvn14WLF-0HBUTbxEIQ1"></script>
# <script>
#     $(document).ready(function() {
#         $('.slide')
#         .scrollSnap({
#             page: 'eventshome'
#         });
#     })
#     </script>
# <ul class="content-list events-border">
# <li class="alt nobreak">
# <section class="content clearfix">
# <h1 class="listing-heading heading">Popular events in Texas</h1>
# <div class="strip slide small" data-type="events" id="events-listing">
# <ul class="list small clearfix popular" style="padding: 0;">
# <li class="">
# <article class="highlight-top">
# <p>Fri, 15 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1310517"><img class="nohide" src="/images/events/flyer/2019/11/us-1115-1310517-list.jpg"/></a>
# <p class="counter nohide">
# <span>12</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1310517">
# <h1>
# Disrupt presents DJ W!ld
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=164420">Bauhaus</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 16 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1309067"><img class="nohide" src="/images/events/flyer/2019/11/us-1116-1309067-list.jpg"/></a>
# <p class="counter nohide">
# <span>13</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1309067">
# <h1>
# Seismic Dance Event
# </h1>
# </a>
# <p class="copy nohide">
# Austin American Statesman
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 23 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1338477"><img class="nohide" src="/images/events/flyer/2019/11/us-1109-1338477-list.jpg"/></a>
# <p class="counter nohide">
# <span>5</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1338477">
# <h1>
# Klubhaus 004
# </h1>
# </a>
# <p class="copy nohide">
# Secret Location
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 23 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1330821"><img class="nohide" src="/images/events/flyer/2019/11/us-1123-1330821-list.jpg"/></a>
# <p class="counter nohide">
# <span>4</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1330821">
# <h1>
# Mind Against [Afterlife]
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=164420">Bauhaus</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Wed, 27 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1328205"><img class="nohide" src="/images/events/flyer/2019/11/us-1127-1328205-list.jpg"/></a>
# <p class="counter nohide">
# <span>4</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1328205">
# <h1>
# Spanksgiving // Verlk // Bedrock
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=62829">Boondocks</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Fri, 29 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1325278"><img class="nohide" src="/images/events/flyer/2019/11/us-1129-1325278-list.jpg"/></a>
# <p class="counter nohide">
# <span>4</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1325278">
# <h1>
# Praia at Night Feat. Carlo Lio B2B Nathan Barato
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=164420">Bauhaus</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 30 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1327056"><img class="nohide" src="/images/events/flyer/2019/11/us-1130-1327056-list.jpg"/></a>
# <p class="counter nohide">
# <span>5</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1327056">
# <h1>
# Kinda Super Disco // Erick Morillo
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=17665">Numbers</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sun, 8 Dec 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1332895"><img class="nohide" src="/images/events/flyer/2019/12/us-1208-1332895-list.jpg"/></a>
# <p class="counter nohide">
# <span>4</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1332895">
# <h1>
# Steve Lawler (Viva Music)
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=132641">Club Here I Love You</a>
# </p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a></a>
# </div>
# <script>
#                             googleAnalytics.sendEventDataOnLoad('events-page', 'popular-events-loaded');
#                        </script>
# </section>
# <section class="iOSOnly content">
# <ul class="phones">
# <li class="f12 pb4 grey">Want RA listings on your mobile?</li>
# <li>
# <div class="but"><a href="https://itunes.apple.com/app/apple-store/id981952703?mt=8">Download the RA Guide</a></div>
# </li>
# </ul>
# </section>
# <div class="banner clearfix">
# <div id="pnlECTOSlot1" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-0"></div>
# </div>
# </div>
# </li>
# <li class="clearfix pt1">
# <div class="page-items content" id="previous-next">
# <ul>
# <li class="but arrow-left left" id="liPrevious">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/us/texas/week/2019-11-07">Previous </a>
# </li><li class="but arrow-right right" id="liNext">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/texas/week/2019-11-21">Next </a>
# </li>
# </ul>
# </div>
# <div class="content clearfix">
# <div class="plus8">
# <div>
# <script src="/bundles/area-country-date-filter-js?v=Q02f5CsIXWPDeOtgJVocYJrwjcQrf96m1qneHFerLLA1"></script>
# <ul class="clearfix classic" data-enableevent="True" id="ulButtons">
# <li class="but arrow-down right" id="liCountry">
# <input id="hdnCountryId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnCountryId" type="hidden" value="2"/>
# <span>US</span><input id="country-name" type="hidden" value="United States of America"/><ul class="links" style="display: none;"><li data-id="7"><a href="/events">Canada</a></li><li data-id="15"><a href="/events">France</a></li><li data-id="12"><a href="/events">Germany</a></li><li data-id="20"><a href="/events">Italy</a></li><li data-id="6"><a href="/events">Netherlands</a></li><li data-id="5"><a href="/events">Spain</a></li><li data-id="3"><a href="/events">United Kingdom</a></li><li class="selected" data-id="2"><a href="/events">United States of America</a></li><li data-id="0"><a href="/events">------------</a></li><li data-id="99"><a href="/events">Albania</a></li><li data-id="125"><a href="/events">Algeria</a></li><li data-id="113"><a href="/events">Andorra</a></li><li data-id="127"><a href="/events">Angola</a></li><li data-id="140"><a href="/events">Antigua and Barbuda</a></li><li data-id="16"><a href="/events">Argentina</a></li><li data-id="106"><a href="/events">Armenia</a></li><li data-id="1"><a href="/events">Australia</a></li><li data-id="57"><a href="/events">Austria</a></li><li data-id="108"><a href="/events">Azerbaijan</a></li><li data-id="117"><a href="/events">Bahamas</a></li><li data-id="80"><a href="/events">Bahrain</a></li><li data-id="107"><a href="/events">Bangladesh</a></li><li data-id="73"><a href="/events">Barbados</a></li><li data-id="76"><a href="/events">Belarus</a></li><li data-id="29"><a href="/events">Belgium</a></li><li data-id="34"><a href="/events">Belize</a></li><li data-id="141"><a href="/events">Benin</a></li><li data-id="126"><a href="/events">Bermuda</a></li><li data-id="142"><a href="/events">Bhutan</a></li><li data-id="85"><a href="/events">Bolivia</a></li><li data-id="74"><a href="/events">Bosnia and Herzegovina</a></li><li data-id="143"><a href="/events">Botswana</a></li><li data-id="28"><a href="/events">Brazil</a></li><li data-id="47"><a href="/events">Bulgaria</a></li><li data-id="144"><a href="/events">Burkina Faso</a></li><li data-id="110"><a href="/events">Cambodia</a></li><li data-id="145"><a href="/events">Cameroon</a></li><li data-id="7"><a href="/events">Canada</a></li><li data-id="92"><a href="/events">Cayman Islands</a></li><li data-id="25"><a href="/events">Chile</a></li><li data-id="30"><a href="/events">China</a></li><li data-id="59"><a href="/events">Colombia</a></li><li data-id="10"><a href="/events">Costa Rica</a></li><li data-id="146"><a href="/events">Cote d'Ivoire</a></li><li data-id="46"><a href="/events">Croatia</a></li><li data-id="102"><a href="/events">Cuba</a></li><li data-id="129"><a href="/events">Curacao</a></li><li data-id="82"><a href="/events">Cyprus</a></li><li data-id="49"><a href="/events">Czech Republic</a></li><li data-id="147"><a href="/events">Democratic Republic of the Congo</a></li><li data-id="51"><a href="/events">Denmark</a></li><li data-id="66"><a href="/events">Dominican Republic</a></li><li data-id="72"><a href="/events">Ecuador</a></li><li data-id="48"><a href="/events">Egypt</a></li><li data-id="54"><a href="/events">El Salvador</a></li><li data-id="71"><a href="/events">Estonia</a></li><li data-id="160"><a href="/events">Ethiopia</a></li><li data-id="158"><a href="/events">Fiji</a></li><li data-id="41"><a href="/events">Finland</a></li><li data-id="15"><a href="/events">France</a></li><li data-id="148"><a href="/events">Gambia</a></li><li data-id="75"><a href="/events">Georgia</a></li><li data-id="12"><a href="/events">Germany</a></li><li data-id="149"><a href="/events">Ghana</a></li><li data-id="103"><a href="/events">Gibraltar</a></li><li data-id="13"><a href="/events">Greece</a></li><li data-id="116"><a href="/events">Guam</a></li><li data-id="87"><a href="/events">Guatemala</a></li><li data-id="63"><a href="/events">Honduras</a></li><li data-id="39"><a href="/events">Hungary</a></li><li data-id="86"><a href="/events">Iceland</a></li><li data-id="58"><a href="/events">India</a></li><li data-id="37"><a href="/events">Indonesia</a></l ...
# </li>
# <li class="but arrow-down right" id="liArea">
# <input id="btnArea" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$btnArea" style="display:none;" type="submit" value="">
# <input id="hdnAreaId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnAreaId" type="hidden" value="318"/>
# <span>Texas</span><ul class="links" style="display: none;"><li class="parent" data-id="108"><a href="/events">Alabama</a></li><li class="parent" data-id="109"><a href="/events">Alaska</a></li><li class="parent" data-id="102"><a href="/events">Arizona</a></li><li class="parent" data-id="110"><a href="/events">Arkansas</a></li><li class="parent" data-id="308"><a href="/events">California</a></li><li data-id="23"><a href="/events">   Los Angeles</a></li><li data-id="310"><a href="/events">   Sacramento</a></li><li data-id="309"><a href="/events">   San Diego</a></li><li data-id="218"><a href="/events">   San Francisco</a></li><li class="parent" data-id="82"><a href="/events">Colorado</a></li><li class="parent" data-id="111"><a href="/events">Connecticut</a></li><li class="parent" data-id="112"><a href="/events">Delaware</a></li><li class="parent" data-id="317"><a href="/events">Florida</a></li><li data-id="314"><a href="/events">   Jacksonville</a></li><li data-id="38"><a href="/events">   Miami</a></li><li data-id="315"><a href="/events">   Orlando</a></li><li data-id="316"><a href="/events">   Tampa Bay</a></li><li class="parent" data-id="64"><a href="/events">Georgia</a></li><li class="parent" data-id="133"><a href="/events">Hawaii</a></li><li class="parent" data-id="113"><a href="/events">Idaho</a></li><li class="parent" data-id="359"><a href="/events">Illinois</a></li><li data-id="17"><a href="/events">   Chicago</a></li><li class="parent" data-id="85"><a href="/events">Indiana</a></li><li class="parent" data-id="114"><a href="/events">Iowa</a></li><li class="parent" data-id="90"><a href="/events">Kansas</a></li><li class="parent" data-id="115"><a href="/events">Kentucky</a></li><li class="parent" data-id="65"><a href="/events">Louisiana</a></li><li class="parent" data-id="116"><a href="/events">Maine</a></li><li class="parent" data-id="117"><a href="/events">Maryland</a></li><li class="parent" data-id="79"><a href="/events">Massachusetts</a></li><li class="parent" data-id="360"><a href="/events">Michigan</a></li><li data-id="19"><a href="/events">   Detroit</a></li><li class="parent" data-id="81"><a href="/events">Minnesota</a></li><li class="parent" data-id="103"><a href="/events">Mississippi</a></li><li class="parent" data-id="118"><a href="/events">Missouri</a></li><li class="parent" data-id="119"><a href="/events">Montana</a></li><li class="parent" data-id="120"><a href="/events">Nebraska</a></li><li class="parent" data-id="47"><a href="/events">Nevada</a></li><li class="parent" data-id="121"><a href="/events">New Hampshire</a></li><li class="parent" data-id="48"><a href="/events">New Jersey</a></li><li class="parent" data-id="122"><a href="/events">New Mexico</a></li><li class="parent" data-id="8"><a href="/events">New York</a></li><li data-id="443"><a href="/events">   Buffalo/Rochester</a></li><li class="parent" data-id="123"><a href="/events">North Carolina</a></li><li class="parent" data-id="124"><a href="/events">North Dakota</a></li><li class="parent" data-id="84"><a href="/events">Ohio</a></li><li class="parent" data-id="104"><a href="/events">Oklahoma</a></li><li class="parent" data-id="410"><a href="/events">Oregon</a></li><li data-id="125"><a href="/events">   Portland</a></li><li class="parent" data-id="80"><a href="/events">Pennsylvania</a></li><li class="parent" data-id="127"><a href="/events">Rhode Island</a></li><li class="parent" data-id="105"><a href="/events">South Carolina</a></li><li class="parent" data-id="128"><a href="/events">South Dakota</a></li><li class="parent" data-id="72"><a href="/events">Tennessee</a></li><li class="parent selected" data-id="318"><a href="/events">Texas</a></li><li data-id="321"><a href="/events">   Austin</a></li><li data-id="319"><a href="/events">   Dallas/Fort Worth</a></li><li data-id="322"><a href="/events">   El Paso</a></li><li data-id="63"><a href="/events">   Houston</a></li><li data-id="320"><a href="/events">   San Antonio</a></li><li class="parent" data-id=" ...
# </input></li>
# <li class="but arrow-down right" id="liDate">
# <input id="btnDateRange" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$btnDateRange" style="display:none;" type="submit" value=""/>
# <input id="hdnDateRange" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnDateRange" type="hidden" value="2"/>
# <span data-id="2">By week</span><ul class="links" style="display: none;"><li data-id="1"><a href="/events/us/texas/default/0-0-0">By day</a></li><li class="selected" data-id="2"><a href="/events/us/texas/default/0-0-0">By week</a></li><li data-id="3"><a href="/events/us/texas/default/0-0-0">By month</a></li></ul>
# </li>
# </ul>
# </div>
# <div class="fl col4" id="event-listing">
# <ul class="list" id="items">
# <li><p class="eventDate date"><a href="/events.aspx?ai=318&amp;v=day&amp;mn=11&amp;yr=2019&amp;dy=15"><span>Fri, 15 Nov 2019 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-11-15T00:00" itemprop="startDate">2019-11-15T00:00</time></span><a href="/events/1310517"><img height="76" src="/images/events/flyer/2019/11/us-1115-1310517-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1310517" itemprop="url" title="Event details of Disrupt presents DJ W!ld">Disrupt presents DJ W!ld</a> <span>at <a href="/club.aspx?id=164420">Bauhaus</a>, <a href="/events.aspx?ai=63">Houston</a></span></h1><div class="grey event-lineup">DJ W!LD, Memo Sepulveda, Hector Moran, Gabo</div><p class="attending"><span>12</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-11-15T00:00" itemprop="startDate">2019-11-15T00:00</time></span><a href="/events/1330380"><img height="76" src="/images/events/flyer/dj/prokfitch-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1330380" itemprop="url" title="Event details of Prok - Fitch">Prok - Fitch</a> <span>at <a href="/club.aspx?id=113432">RBC</a>, <a href="/events.aspx?ai=319">Dallas/Fort Worth</a></span></h1><div class="grey event-lineup">Prok &amp; Fitch</div><p class="attending"><span>3</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-11-15T00:00" itemprop="startDate">2019-11-15T00:00</time></span><a href="/events/1313498"><img height="76" src="/images/events/flyer/2019/11/us-1115-1313498-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1313498" itemprop="url" title="Event details of Fleetmac Wood presents Sea of Love Disco - Austin">Fleetmac Wood presents Sea of Love Disco - Austin</a> <span>at <a href="/club.aspx?id=13614">The Parish</a>, <a href="/events.aspx?ai=321">Austin</a></span></h1><div class="grey event-lineup">Roxanne Roll, Smooth Sailing</div><p class="attending"><span>2</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-11-15T00:00" itemprop="startDate">2019-11-15T00:00</time></span><a href="/events/1343314"><img height="76" src="/images/events/flyer/2019/11/us-1115-1343314-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1343314" itemprop="url" title="Event details of Be Careful with Shyboi">Be Careful with Shyboi</a> <span>at <a href="/club.aspx?id=142550">The Dive</a>, <a href="/events.aspx?ai=63">Houston</a></span></h1><div class="grey event-lineup">Shyboi, Skinny Play, Kay Illah, Vacio Sur, Mano Pantea</div><p class="attending"><span>1</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-11-15T00:00" itemprop="startDate">2019-11-15T00:00</time></span><a href="/events/1345397"><img height="76" src="/images/events/flyer/2019/11/us-1115-1345397-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1345397" itemprop="url" title="Event details of Toxic">Toxic</a> <span>at <span class="grey" style="display:inline;">Warehouse 15</span>, <a href="/events.aspx?ai=320">San Antonio</a></span></h1><div class="grey event-lineup">dlancey, Ed Rhymes, Redwood, Mylee, Emma</div><p class="attending"><span>1</span> Attending</p></div></article></li ...
# </ul>
# </div>
# <div class="fl col2" style="padding-top: 88px;">
# <div class="pr8 sticky">
# <section id="calendar">
# <div class="h-align">
# <h1 class="heading">Calendar</h1>
# </div>
# <div id="calendar-inner">
# <select id="ddlCalendarMonth" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarMonth" style="width:104px;">
# <option value="12">December</option>
# <option selected="selected" value="11">November</option>
# <option value="10">October</option>
# <option value="9">September</option>
# <option value="8">August</option>
# <option value="7">July</option>
# <option value="6">June</option>
# <option value="5">May</option>
# <option value="4">April</option>
# <option value="3">March</option>
# <option value="2">February</option>
# <option value="1">January</option>
# </select>
# <select id="ddlCalendarYear" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarYear">
# <option value="2020">2020</option>
# <option selected="selected" value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# </select>
# <select id="ddlCalendarType" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarType" style="width:104px;">
# <option value="day">By day</option>
# <option selected="selected" value="week">By week</option>
# <option value="month">By month</option>
# </select>
# <input id="hfCalendarDayOfWeek" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$hfCalendarDayOfWeek" type="hidden" value="15"/>
# <table><tr><th>Sun</th><th>Mon</th><th>Tue</th><th>Wed</th><th>Thu</th><th>Fri</th><th>Sat</th></tr><tr><td><a class="day-off" href="/events/us/texas/week/2019-10-27">27</a></td><td><a class="day-off" href="/events/us/texas/week/2019-10-28">28</a></td><td><a class="day-off" href="/events/us/texas/week/2019-10-29">29</a></td><td><a class="day-off" href="/events/us/texas/week/2019-10-30">30</a></td><td><a class="day-off" href="/events/us/texas/week/2019-10-31">31</a></td><td><a href="/events/us/texas/week/2019-11-01">1</a></td><td><a href="/events/us/texas/week/2019-11-02">2</a></td></tr><tr><td><a href="/events/us/texas/week/2019-11-03">3</a></td><td><a href="/events/us/texas/week/2019-11-04">4</a></td><td><a href="/events/us/texas/week/2019-11-05">5</a></td><td><a href="/events/us/texas/week/2019-11-06">6</a></td><td><a href="/events/us/texas/week/2019-11-07">7</a></td><td><a href="/events/us/texas/week/2019-11-08">8</a></td><td><a href="/events/us/texas/week/2019-11-09">9</a></td></tr><tr><td><a href="/events/us/texas/week/2019-11-10">10</a></td><td><a href="/events/us/texas/week/2019-11-11">11</a></td><td><a href="/events/us/texas/week/2019-11-12">12</a></td><td><a href="/events/us/texas/week/2019-11-13">13</a></td><td><a href="/events/us/texas/week/2019-11-14">14</a></td><td><span class="day-current">15</span></td><td><a href="/events/us/texas/week/2019-11-16">16</a></td></tr><tr><td><a href="/events/us/texas/week/2019-11-17">17</a></td><td><a href="/events/us/texas/week/2019-11-18">18</a></td><td><a href="/events/us/texas/week/2019-11-19">19</a></td><td><a href="/events/us/texas/week/2019-11-20">20</a></td><td><a href="/events/us/texas/week/2019-11-21">21</a></td><td><a href="/events/us/texas/week/2019-11-22">22</a></td><td><a href="/events/us/texas/week/2019-11-23">23</a></td></tr><tr><td><a href="/events/us/texas/week/2019-11-24">24</a></td><td><a href="/events/us/texas/week/2019-11-25">25</a></td><td><a href="/events/us/texas/week/2019-11-26">26</a></td><td><a href="/events/us/texas/week/2019-11-27">27</a></td><td><a href="/events/us/texas/week/2019-11-28">28</a></td><td><a href="/events/us/texas/week/2019-11-29">29</a></td><td><a href="/events/us/texas/week/2019-11-30">30</a></td></tr></table>
# </div>
# <script type="text/javascript">
# 		$("#ddlCalendarMonth, #ddlCalendarYear, #ddlCalendarType").change(function () {
#             var aSearch = location.search.indexOf("&") > 0
#                 ? location.search.split('&')
#                 : "";
#
# 			var sQueryString;
#
#             var month = $('#ddlCalendarMonth').val().length === 2
#                 ? $('#ddlCalendarMonth').val()
#                 : "0" + $('#ddlCalendarMonth').val();
#
#             var day = $('#hfCalendarDayOfWeek').val().length === 2
#                 ? $('#hfCalendarDayOfWeek').val()
#                 : "0" + $('#hfCalendarDayOfWeek').val();
#
#             var area = $('#liArea span').text().replace(/[^A-Z0-9]/ig, '').toLowerCase() === 'all'
#                 ? ""
#                 : $('#liArea span').text().replace(/[^A-Z0-9]/ig, '').toLowerCase() + "/";
#
#             var country = area === ''
#                 ? $('#country-name').val()
#                 : $('#liCountry span').text()
#
# 			sQueryString = "/events/"
#                 + country.replace(/[^A-Z0-9]/ig, '').toLowerCase() + "/"
#                 + area
#                 + $('#ddlCalendarType').val() + "/"
# 				+ $('#ddlCalendarYear').val() + "-"
#                 + month + "-"
# 				+ day;
#
# 			location.href = sQueryString;
# 		});
# 	</script>
# </section>
# <div class="banner">
# <div id="pnlMPU">
# <div class="ad" id="div-gpt-ad-1452773484957-7" style="width: 300px; min-height: 250px; padding-bottom: 10px;"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="fl col2 h-align-toplist">
# <div class="mr8">
# <section class="top-list generic events" id="toplist">
# <h1 class="heading">Top Texas clubs</h1>
# <ul>
# <li><a ga-event-action="Kingdom Nightclub" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=52645">Kingdom Nightclub</a> /</li><li><a ga-event-action="Plush" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=5107">Plush</a> /</li><li><a ga-event-action="It'll Do" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=97698">It'll Do</a> /</li><li><a ga-event-action="Lizard Lounge" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=1683">Lizard Lounge</a> /</li><li><a ga-event-action="Jet Lounge" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=5334">Jet Lounge</a> /</li><li><a ga-event-action="Rich's at 2401" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=1512">Rich's at 2401</a> /</li><li><a ga-event-action="The Techno Bunker" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=134926">The Techno Bunker</a> /</li><li><a ga-event-action="Barcelona" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=3258">Barcelona</a> /</li><li><a ga-event-action="Stereo Live" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=7408">Stereo Live</a> /</li><li><a ga-event-action="Boiler Room" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=40612">Boiler Room</a> /</li><li><a ga-event-action="Vulcan Gas Company" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=91560">Vulcan Gas Company</a> /</li><li><a ga-event-action="Ethics Music Lounge" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=115109">Ethics Music Lounge</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-clubs" ga-on="click" href="/clubs.aspx?ai=318">More Texas clubs</a></div>
# </section><section class="top-list generic events" id="toplist">
# <h1 class="heading">Top 20 regions</h1>
# <ul>
# <li><a ga-event-action="London" ga-event-category="top-regions" ga-on="click" href="/guide/uk/london">London, UK</a> /</li><li><a ga-event-action="Berlin" ga-event-category="top-regions" ga-on="click" href="/guide/de/berlin">Berlin, DE</a> /</li><li><a ga-event-action="New York" ga-event-category="top-regions" ga-on="click" href="/guide/us/newyork">New York, US</a> /</li><li><a ga-event-action="Tokyo" ga-event-category="top-regions" ga-on="click" href="/guide/jp/tokyo">Tokyo, JP</a> /</li><li><a ga-event-action="Paris" ga-event-category="top-regions" ga-on="click" href="/guide/fr/paris">Paris, FR</a> /</li><li><a ga-event-action="Amsterdam" ga-event-category="top-regions" ga-on="click" href="/guide/nl/amsterdam">Amsterdam, NL</a> /</li><li><a ga-event-action="Barcelona" ga-event-category="top-regions" ga-on="click" href="/guide/es/barcelona">Barcelona, ES</a> /</li><li><a ga-event-action="Manchester" ga-event-category="top-regions" ga-on="click" href="/guide/uk/manchester">Manchester, UK</a> /</li><li><a ga-event-action="Los Angeles" ga-event-category="top-regions" ga-on="click" href="/guide/us/losangeles">Los Angeles, US</a> /</li><li><a ga-event-action="Melbourne" ga-event-category="top-regions" ga-on="click" href="/guide/au/melbourne">Melbourne, AU</a> /</li><li><a ga-event-action="Miami" ga-event-category="top-regions" ga-on="click" href="/guide/us/miami">Miami, US</a> /</li><li><a ga-event-action="Sydney" ga-event-category="top-regions" ga-on="click" href="/guide/au/sydney">Sydney, AU</a> /</li><li><a ga-event-action="Madrid" ga-event-category="top-regions" ga-on="click" href="/guide/es/madrid">Madrid, ES</a> /</li><li><a ga-event-action="San Francisco" ga-event-category="top-regions" ga-on="click" href="/guide/us/sanfrancisco">San Francisco, US</a> /</li><li><a ga-event-action="Glasgow" ga-event-category="top-regions" ga-on="click" href="/guide/uk/glasgow">Glasgow, UK</a> /</li><li><a ga-event-action="South + East" ga-event-category="top-regions" ga-on="click" href="/guide/uk/southeast">South + East, UK</a> /</li><li><a ga-event-action="Leeds" ga-event-category="top-regions" ga-on="click" href="/guide/uk/leeds">Leeds, UK</a> /</li><li><a ga-event-action="Brussels" ga-event-category="top-regions" ga-on="click" href="/guide/be/brussels">Brussels, BE</a> /</li><li><a ga-event-action="North" ga-event-category="top-regions" ga-on="click" href="/guide/it/north">North, IT</a> /</li><li><a ga-event-action="Milan" ga-event-category="top-regions" ga-on="click" href="/guide/it/milan">Milan, IT</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-regions" ga-on="click" href="/events.aspx?show=all">More regions</a></div>
# </section><div id="pnlSkyscraper">
# <div class="ad mobile-off" id="div-gpt-ad-1452773484957-12" style="width: 160px; height: 600px;"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-items content sub clearfix">
# <ul>
# <li class="but arrow-left left" id="liPrevious2">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/us/texas/week/2019-11-07">Previous </a>
# </li><li class="but arrow-right right" id="liNext2">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/texas/week/2019-11-21">Next </a>
# </li>
# </ul>
# </div>
# <div class="banner clearfix">
# <div id="pnlECTOSlot2" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-1"></div>
# </div>
# </div>
# <br/>
# <span>01 /</span>
# </li>
# <li class="alt">
# <section class="content" id="popular-news">
# <h1 class="heading listing-heading">Most popular news</h1>
# <div class="but heading-more mobile-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# <div class="strip small slide" data-type="news" id="news-listing">
# <ul class="list">
# <li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 12 Nov 2019</p>
# <a href="/news/71032">
# <img class="thumb" src="/images/news/2019/berghain-berlin-15-years.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71032/?comments=1">Post a comment</a>
# </p><a href="/news/71032">
# <h1>Berghain is throwing a 15th birthday party</h1>
# </a>
# <p class="copy">The Berlin club will host Surgeon, Caterina Barbieri and more across three rooms, with doors opening on Saturday, December 14th.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 13 Nov 2019</p>
# <a href="/news/71043">
# <img class="thumb" src="/images/news/2019/fold-license-suspension.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71043/?comments=1">Post a comment</a>
# </p><a href="/news/71043">
# <h1>London venue FOLD ordered to shut by Newham Council over fraud allegations</h1>
# </a>
# <p class="copy">The Canning Town club's license has been suspended as a money laundering investigation by the National Crime agency is underway.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 11 Nov 2019</p>
# <a href="/news/71020">
# <img class="thumb" src="/images/news/2019/lofi-amsterdam-new-club.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71020/?comments=1">Post a comment</a>
# </p><a href="/news/71020">
# <h1>Amsterdam gets new club, Lofi</h1>
# </a>
# <p class="copy">The Sloterdijk venue opened in October.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 08 Nov 2019</p>
# <a href="/news/71004">
# <img class="thumb" src="/images/news/2019/behringer-303-roland-clone.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71004/?comments=1">Post a comment</a>
# </p><a href="/news/71004">
# <h1>Behringer's Roland TB-303 clone leaked</h1>
# </a>
# <p class="copy">The TD-3 synth appeared on Behringer's website before being removed.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 08 Nov 2019</p>
# <a href="/news/71006">
# <img class="thumb" src="/images/news/2019/orange-yard-new-soho-london-venue.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71006/?comments=1">Post a comment</a>
# </p><a href="/news/71006">
# <h1>New club Orange Yard opens in central London</h1>
# </a>
# <p class="copy">The team behind E1 London took over the Soho basement space that used to house The Borderline.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 08 Nov 2019</p>
# <a href="/news/71005">
# <img class="thumb" src="/images/news/2019/d-double-e-ikea-christmas-advert-uk-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71005/?comments=1">Post a comment</a>
# </p><a href="/news/71005">
# <h1>Grime MC D Double E soundtracks new IKEA Christmas advert</h1>
# </a>
# <p class="copy">"This place ain't bless, this place is a mess," he delivers in the Swedish furniture company's first-ever holiday spot.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 14 Nov 2019</p>
# <a href="/news/71054">
# <img class="thumb" src="/images/news/2019/four-tet-lot-radio.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71054/?comments=1">Post a comment</a>
# </p><a href="/news/71054">
# <h1>Mix Of The Day: Four Tet</h1>
# </a>
# <p class="copy">Kieran Hebden goes live on New York City's The Lot Radio.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 13 Nov 2019</p>
# <a href="/news/71047">
# <img class="thumb" src="/images/news/2019/joy-overmono-new-single-collaboration.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71047/?comments=1">Post a comment</a>
# </p><a href="/news/71047">
# <h1>Joy Orbison and Overmono join forces on new XL 12-inch as Joy Overmono</h1>
# </a>
# <p class="copy">You can stream "Bromley" now.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 12 Nov 2019</p>
# <a href="/news/71028">
# <img class="thumb" src="/images/news/2019/phase-croydon.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71028/?comments=1">Post a comment</a>
# </p><a href="/news/71028">
# <h1>London is getting a new club called Phase</h1>
# </a>
# <p class="copy">The 500-capacity venue will open in Croydon this December.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 11 Nov 2019</p>
# <a href="/news/71021">
# <img class="thumb" src="/images/news/2019/drexciya-exhibition-zurich.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71021/?comments=1">Post a comment</a>
# </p><a href="/news/71021">
# <h1>A Drexciya exhibition is happening in Zürich</h1>
# </a>
# <p class="copy">Bubble Chamber opens November 15th.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Sat, 09 Nov 2019</p>
# <a href="/news/71010">
# <img class="thumb" src="/images/news/2019/dj-voices-motd.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71010/?comments=1">Post a comment</a>
# </p><a href="/news/71010">
# <h1>Mix Of The Day: DJ Voices</h1>
# </a>
# <p class="copy">Slowed-down grooves, trippy techno and weirdo beats from an essential New York DJ.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 12 Nov 2019</p>
# <a href="/news/71031">
# <img class="thumb" src="/images/news/2019/whp-nyd-2020.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71031/?comments=1">Post a comment</a>
# </p><a href="/news/71031">
# <h1>The Warehouse Project announces NYD 2020 lineup</h1>
# </a>
# <p class="copy">Seth Troxler, Joy Orbison, Helena Hauff and more will play Depot in Manchester on January 1st.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 13 Nov 2019</p>
# <a href="/news/71033">
# <img class="thumb" src="/images/news/2019/gilles-peterson-press-shot.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71033/?comments=1">Post a comment</a>
# </p><a href="/news/71033">
# <h1>Gilles Peterson reissues Tino Contreras' Musica Infinita via new label, Arc Records</h1>
# </a>
# <p class="copy">The three-track jazz record, originally released in 1978, arrives on January 10th, 2020.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 12 Nov 2019</p>
# <a href="/news/71034">
# <img class="thumb" src="/images/news/2019/quantum.nyc.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71034/?comments=1">Post a comment</a>
# </p><a href="/news/71034">
# <h1>Brooklyn club Analog BKNY becomes Quantum, reveals 2019 program</h1>
# </a>
# <p class="copy">The rebranded venue comes with a restructured management team and production.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 08 Nov 2019</p>
# <a href="/news/71013">
# <img class="thumb" src="/images/news/2019/zigtrax.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71013/?comments=1">Post a comment</a>
# </p><a href="/news/71013">
# <h1>Workshop's next release is an album from Zigtrax, AKA Kassem Mosse, Mix Mup and Tapes</h1>
# </a>
# <p class="copy">The eight-track LP is out now.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 08 Nov 2019</p>
# <a href="/news/71003">
# <img class="thumb" src="/images/news/2019/chilean-protests-compilation-despertar-chile-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71003/?comments=1">Post a comment</a>
# </p><a href="/news/71003">
# <h1>Valesuchi, Silent Servant contribute to 51-track benefit compilation, Despertar: Chile</h1>
# </a>
# <p class="copy">It'll aid human rights organizations as the South American country experiences extreme political unrest.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 07 Nov 2019</p>
# <a href="/news/70998">
# <img class="thumb" src="/images/news/2019/flying-lotus-adult-swim.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/70998/?comments=1">Post a comment</a>
# </p><a href="/news/70998">
# <h1>Adult Swim announces 2019 Singles program with Flying Lotus, DJ Haram, serpentwithfeet</h1>
# </a>
# <p class="copy">The year-long program also includes tracks from SWAN, Mary Lattimore and DJ Paypal.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 08 Nov 2019</p>
# <a href="/news/71008">
# <img class="thumb" src="/images/news/2019/fiedel.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71008/?comments=1">Post a comment</a>
# </p><a href="/news/71008">
# <h1>Fiedel launches sub-label and 12-inch series, Super Sound Tool</h1>
# </a>
# <p class="copy">The Berghain resident has just released the imprint's first record, Super Sound Tool #1.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 12 Nov 2019</p>
# <a href="/news/70958">
# <img class="thumb" src="/images/news/2019/maceo-plex-studios.png"/>
# </a>
# <p class="comments light">
# <a href="/news/70958/?comments=1">Post a comment</a>
# </p><a href="/news/70958">
# <h1>Maceo Plex donates hardware to Bridge 48 Studios in Barcelona</h1>
# </a>
# <p class="copy">Get creative with a wide selection of the US artist's synths, drum machines, speakers and more.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 08 Nov 2019</p>
# <a href="/news/70994">
# <img class="thumb" src="/images/news/2019/mighty-zaf-motd.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/70994/?comments=1">Post a comment</a>
# </p><a href="/news/70994">
# <h1>Mix Of The Day: The Mighty Zaf</h1>
# </a>
# <p class="copy">"Starts off soft, once it gets going and starts to climax it gets a bit harder, but then finishes off soft again. A lovely experience... try it out."</p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# </section>
# <span>02 /</span>
# </li>
# </ul>
# </main>
# </form>
# <footer class="clearfix"><ul class="content-list">
# <li>
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col2-3">
# <ul class="pb32">
# <li id="logo-footer"><a href="/">RA</a></li>
# <li class="f12 grey pt16">Copyright © 2019 Resident Advisor Ltd.</li>
# <li class="f12 grey">All rights reserved.</li>
# <li class="f12 grey"><a href="/privacy">Privacy</a> &amp; <a href="/terms">Terms</a></li>
# <li class="f12 grey"><a href="/cookiepolicy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="fl col4-5 pt60">
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Resident Advisor /</li> <li><a ga-event-action="about" ga-event-category="homefooter" ga-on="click" href="/about">About</a></li>
# <li><a ga-event-action="advertise" ga-event-category="homefooter" ga-on="click" href="/about/advertising">Advertise</a></li>
# <li><a ga-event-action="jobs" ga-event-category="homefooter" ga-on="click" href="https://www.doorsopen.co/company/12/resident-advisor/#utm_source=RA&amp;utm_medium=footer-link">Jobs</a></li>
# <li><a ga-event-action="raevents" ga-event-category="homefooter" ga-on="click" href="/features/3214">24/7</a></li>
# <li><br/></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">RA Tickets /</li>
# <li><a ga-event-action="mytickets" ga-event-category="homefooter" ga-on="click" href="/shop/history">My Tickets</a></li>
# <li><a ga-event-action="ticketfaq" ga-event-category="homefooter" ga-on="click" href="/shop/faq">Ticketing FAQ</a></li>
# <li><a ga-event-action="resale" ga-event-category="homefooter" ga-on="click" href="/tickets/resale">Resale</a></li>
# <li><a ga-event-action="selltickets" ga-event-category="homefooter" ga-on="click" href="/tickets">Sell tickets on RA</a></li>
# <li><div class="myra but" style="width: 152px; margin-top: 50px;"><a class="submit-event" ga-event-action="submitevent" ga-event-category="homefooter" ga-on="click" href="/submit-event.aspx">Submit event</a></div></li>
# <li><br/></li>
# </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Apps /</li> <li><a ga-event-action="raguide" ga-event-category="homefooter" ga-on="click" href="/ra-guide">RA Guide</a></li>
# <li><a ga-event-action="ticketscanner" ga-event-category="homefooter" ga-on="click" href="/tickets/scanner">RA Ticket Scanner</a></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Elsewhere /</li>
# <li><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/user/residentadvisor?sub_confirmation=1">Watch on YouTube</a></li>
# <li><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">Follow on Facebook</a></li>
# <li><a ga-event-action="raapplemusic" ga-event-category="homefooter" ga-on="click" href="https://itunes.apple.com/gb/curator/resident-advisor/id996091687">Listen on Apple Music</a></li>
# <li><a ga-event-action="raspotify" ga-event-category="homefooter" ga-on="click" href="https://open.spotify.com/user/residentadvisor">Stream on Spotify</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nobreak">
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col3">
# <a href="https://jp.residentadvisor.net/"><a href="https://jp.residentadvisor.net/">RA is also available in Japanese. 日本版</a></a>
# </div>
# <ul class="col1p5" id="social">
# <li class="ytb"><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/residentadvisor">RA on YouTube</a></li>
# <li class="fcb"><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">RA on Facebook</a></li>
# <li class="twt"><a ga-event-action="ratwitter" ga-event-category="homefooter" ga-on="click" href="http://www.twitter.com/residentadvisor">RA on Twitter</a></li>
# <li class="ins"><a ga-event-action="rainstagram" ga-event-category="homefooter" ga-on="click" href="http://instagram.com/resident_advisor">RA on Instagram</a></li>
# <li class="snd"><a ga-event-action="rasoundcloud" ga-event-category="homefooter" ga-on="click" href="http://www.soundcloud.com/resident-advisor">RA on Soundcloud</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul></footer>
# <script type="text/javascript">
#         (function(i, s, o, g, r, a, m) {
#                                         i['GoogleAnalyticsObject'] = r;
#                                         i[r] = i[r] || function() {
#                                             (i[r].q = i[r].q || []).push(arguments)
#                                         }, i[r].l = 1 * new Date();
#                                         a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#                                         a.async = 1;
#                                         a.src = g;
#                                         m.parentNode.insertBefore(a, m)
#                                     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#                                     ga('create', 'UA-313318-1', 'residentadvisor.net'
#                                     );
#                                     ga('require', 'displayfeatures');
#                                     ga('send', 'pageview');
#                                     ga('require', 'eventTracker');
#
#         if (window.location.href.indexOf('.residentadvisor.net') >= 0 && window.location.pathname.indexOf('submit-event') === 0) {
# 	        (function(r, a, v, e, l, i, n) {
# 	            r[l] = r[l] || function() { (r[l].q = r[l].q || []).push(arguments) };
# 	            i = a.createElement(v);
# 	            i.async = i.defer = 1;
# 	            i.src = e;
# 	            a.body.appendChild(i)
# 	        })(window, document, 'script', 'https://cdn.ravelin.net/js/rvn-beta.min.js', 'ravelin');
# 	        ravelin('setApiKey', 'pk_live_Z6F2v32uJEQnwn46SLF7xdojmnOPLfAI');
#             ravelin('setCustomerId', '0');
#             ravelin('setCookieDomain', '.residentadvisor.net');
# 	    }
# 	</script>
# <script>
#         cssVars({})
#     </script>
# </body>
# </html>>

# %%
concerts = soup.find('div', class_="fl col4")
concerts
# Out:
# <div class="fl col4" id="event-listing">
# <ul class="list" id="items">
# <li><p class="eventDate date"><a href="/events.aspx?ai=318&amp;v=day&amp;mn=11&amp;yr=2019&amp;dy=15"><span>Fri, 15 Nov 2019 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-11-15T00:00" itemprop="startDate">2019-11-15T00:00</time></span><a href="/events/1310517"><img height="76" src="/images/events/flyer/2019/11/us-1115-1310517-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1310517" itemprop="url" title="Event details of Disrupt presents DJ W!ld">Disrupt presents DJ W!ld</a> <span>at <a href="/club.aspx?id=164420">Bauhaus</a>, <a href="/events.aspx?ai=63">Houston</a></span></h1><div class="grey event-lineup">DJ W!LD, Memo Sepulveda, Hector Moran, Gabo</div><p class="attending"><span>12</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-11-15T00:00" itemprop="startDate">2019-11-15T00:00</time></span><a href="/events/1330380"><img height="76" src="/images/events/flyer/dj/prokfitch-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1330380" itemprop="url" title="Event details of Prok - Fitch">Prok - Fitch</a> <span>at <a href="/club.aspx?id=113432">RBC</a>, <a href="/events.aspx?ai=319">Dallas/Fort Worth</a></span></h1><div class="grey event-lineup">Prok &amp; Fitch</div><p class="attending"><span>3</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-11-15T00:00" itemprop="startDate">2019-11-15T00:00</time></span><a href="/events/1313498"><img height="76" src="/images/events/flyer/2019/11/us-1115-1313498-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1313498" itemprop="url" title="Event details of Fleetmac Wood presents Sea of Love Disco - Austin">Fleetmac Wood presents Sea of Love Disco - Austin</a> <span>at <a href="/club.aspx?id=13614">The Parish</a>, <a href="/events.aspx?ai=321">Austin</a></span></h1><div class="grey event-lineup">Roxanne Roll, Smooth Sailing</div><p class="attending"><span>2</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-11-15T00:00" itemprop="startDate">2019-11-15T00:00</time></span><a href="/events/1343314"><img height="76" src="/images/events/flyer/2019/11/us-1115-1343314-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1343314" itemprop="url" title="Event details of Be Careful with Shyboi">Be Careful with Shyboi</a> <span>at <a href="/club.aspx?id=142550">The Dive</a>, <a href="/events.aspx?ai=63">Houston</a></span></h1><div class="grey event-lineup">Shyboi, Skinny Play, Kay Illah, Vacio Sur, Mano Pantea</div><p class="attending"><span>1</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-11-15T00:00" itemprop="startDate">2019-11-15T00:00</time></span><a href="/events/1345397"><img height="76" src="/images/events/flyer/2019/11/us-1115-1345397-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1345397" itemprop="url" title="Event details of Toxic">Toxic</a> <span>at <span class="grey" style="display:inline;">Warehouse 15</span>, <a href="/events.aspx?ai=320">San Antonio</a></span></h1><div class="grey event-lineup">dlancey, Ed Rhymes, Redwood, Mylee, Emma</div><p class="attending"><span>1</span> Attending</p></div></article></li ...
# </ul>
# </div>

# %%
# function to call on time
def retrieve_time(soup):
    times = [thing.find('time').attrs['datetime'] for thing in soup.findAll('article')]
    return times
retrieve_time(concerts)
# Out:
# ['2019-11-15T00:00',
#  '2019-11-15T00:00',
#  '2019-11-15T00:00',
#  '2019-11-15T00:00',
#  '2019-11-15T00:00',
#  '2019-11-16T00:00',
#  '2019-11-16T00:00',
#  '2019-11-16T00:00',
#  '2019-11-16T00:00',
#  '2019-11-17T00:00',
#  '2019-11-17T00:00']

# %%
#Trobuleshooting code for above cell

# times = [thing.find('time').attrs['datetime'] for thing in concert.findAll('article')]
# len(times)
# times1 = []
# for x in times:
#     times1.append(times[x].findAll('time'))
# times1
# times1 = [times[x].findAll('time') for x in enumerate(times)]
# times1

# %%
# function to call time
def retrieve_names(soup):
    names = [thing.find('h1').find('a').attrs['title'] for thing in soup.findAll('article')]
    new_names = []
    for x in names:
        new_names.append(x.replace('Event details of ', ''))
    return new_names
retrieve_names(concerts)
# Out:
# ['Disrupt presents DJ W!ld',
#  'Prok - Fitch',
#  'Fleetmac Wood presents Sea of Love Disco - Austin',
#  'Be Careful with Shyboi',
#  'Toxic',
#  'Seismic Dance Event',
#  'Lokal with Suciu (Pressure Traxx, Sunrise)',
#  'The Oven Afterhours: Apocolypse Meow: Denied Music Showcase',
#  'Sound Sinners feat. David Gtronic',
#  'Seismic Dance Event',
#  'R U Down']

# %%
# function to call venue
def retrieve_venue(soup):
    venues_href = [thing.find('h1').find('span').find('a') for thing in soup.findAll('article')]
    new_venues = [x.split('>') for x in str(venues_href).split('<')]
    new_venues_list_indices = [i for i in range(1, len(new_venues), 2)]
    new_venues_lists = []
    for j in new_venues_list_indices:
        new_venues_lists.append(new_venues[j])
    new_venue_list = [new_venues_lists[k][1] for k in range(len(new_venues_lists))]
    return new_venue_list
retrieve_venue(concerts)
# Out:
# ['Bauhaus',
#  'RBC',
#  'The Parish',
#  'The Dive',
#  'San Antonio',
#  'Austin',
#  'San Antonio',
#  'The Oven',
#  'Roof 324',
#  'Austin',
#  'The Dive']

# %%
attendees_href = [thing.find('p') for thing in concerts.findAll('article')]
new_attendees = [x.split('</span>') for x in str(attendees_href).split('</p>')]
print(new_attendees)
print(len(new_attendees))
new_attendees_list = [new_attendees[1][i] for i in range(1-len(new_attendees))]
new_attendees_list
# Out:
# [['[<p class="attending"><span>12', ' Attending'], [', <p class="attending"><span>3', ' Attending'], [', <p class="attending"><span>2', ' Attending'], [', <p class="attending"><span>1', ' Attending'], [', <p class="attending"><span>1', ' Attending'], [', <p class="attending"><span>13', ' Attending'], [', <p class="attending"><span>3', ' Attending'], [', <p class="attending"><span>2', ' Attending'], [', <p class="attending"><span>2', ' Attending'], [', <p class="attending"><span>13', ' Attending'], [', None]']]
# 11
# []

# %%
# function to call number of attendees
def retrieve_attendees(soup):
# Out:
#   File "<ipython-input-8-77417afad5a0>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def scrape_events(events_page_url):
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    #Your code here
    return next_page_url

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully scraped a website for concert event information!
